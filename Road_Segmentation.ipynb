# %% [markdown]
# <a href="https://colab.research.google.com/github/JayjeetAtGithub/Computer-Vision-Notebooks/blob/master/Road_Segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (2.21.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests) (1.24.3)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pickle
import cv2
from tqdm import tqdm_notebook
import os
import json
import math
import h5py


from matplotlib.pyplot import imshow
from matplotlib import pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

import os
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import tensorflow as tf
import pandas as pd
from keras.models import Model, load_model
from skimage.morphology import label
import pickle
import tensorflow.keras.backend as K

from matplotlib import pyplot as plt
from tqdm import tqdm_notebook
import random
from skimage.io import imread, imshow, imread_collection, concatenate_images
from matplotlib import pyplot as plt
import h5py

seed = 56
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
# check the image and the masks file
image_file = '/content/drive/My Drive/datasets/train_images.h5py'
mask_file = '/content/drive/My Drive/datasets/target_images.h5py'
print(os.path.exists(image_file))
print(os.path.exists(mask_file))
# Out:
# True
# True

# %%
# get images and masks from h5py files
hfile1 = h5py.File(image_file, 'r')
n1 = hfile1.get('all_train_images')
images = np.array(n1)
print(images.shape)
hfile1.close()

hfile2 = h5py.File(mask_file, 'r')
n2 = hfile2.get('all_target_images')
masks = np.array(n2)
print(masks.shape)
hfile2.close()

masks = np.expand_dims(masks, -1)
# Out:
# (1000, 256, 256, 3)
# (1000, 256, 256)

# %%
# splitting data
from sklearn.model_selection import train_test_split
train_images, test_images, train_masks, test_masks = train_test_split(images, masks, test_size=0.2, random_state=seed)
del images, masks
print("TRAIN SET")
print(train_images.shape)
print(train_masks.shape)
print("TEST SET")
print(test_images.shape)
print(test_masks.shape)
# Out:
# TRAIN SET
# (800, 256, 256, 3)
# (800, 256, 256, 1)
# TEST SET
# (200, 256, 256, 3)
# (200, 256, 256, 1)

# %%
from keras.models import Model, load_model
import tensorflow as tf
from keras.layers import Input
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras import optimizers
from keras.layers import BatchNormalization
from tensorflow.keras.metrics import MeanIoU
import keras

# %%
inputs = Input((256, 256, 3))
s = Lambda(lambda x: x / 255) (inputs)

conv1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (inputs)
conv1 = BatchNormalization() (conv1)
conv1 = Dropout(0.1) (conv1)
conv1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (conv1)
conv1 = BatchNormalization() (conv1)
pooling1 = MaxPooling2D((2, 2)) (conv1)

conv2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (pooling1)
conv2 = BatchNormalization() (conv2)
conv2 = Dropout(0.1) (conv2)
conv2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (conv2)
conv2 = BatchNormalization() (conv2)
pooling2 = MaxPooling2D((2, 2)) (conv2)

conv3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (pooling2)
conv3 = BatchNormalization() (conv3)
conv3 = Dropout(0.2) (conv3)
conv3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (conv3)
conv3 = BatchNormalization() (conv3)
pooling3 = MaxPooling2D((2, 2)) (conv3)

conv4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (pooling3)
conv4 = BatchNormalization() (conv4)
conv4 = Dropout(0.2) (conv4)
conv4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (conv4)
conv4 = BatchNormalization() (conv4)
pooling4 = MaxPooling2D(pool_size=(2, 2)) (conv4)

conv5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (pooling4)
conv5 = BatchNormalization() (conv5)
conv5 = Dropout(0.3) (conv5)
conv5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (conv5)
conv5 = BatchNormalization() (conv5)


upsample6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (conv5)
upsample6 = concatenate([upsample6, conv4])
conv6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (upsample6)
conv6 = BatchNormalization() (conv6)
conv6 = Dropout(0.2) (conv6)
conv6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (conv6)
conv6 = BatchNormalization() (conv6)

upsample7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (conv6)
upsample7 = concatenate([upsample7, conv3])
conv7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (upsample7)
conv7 = BatchNormalization() (conv7)
conv7 = Dropout(0.2) (conv7)
conv7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (conv7)
conv7 = BatchNormalization() (conv7)

upsample8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (conv7)
upsample8 = concatenate([upsample8, conv2])
conv8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (upsample8)
conv8 = BatchNormalization() (conv8)
conv8 = Dropout(0.1) (conv8)
conv8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (conv8)
conv8 = BatchNormalization() (conv8)

upsample9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (conv8)
upsample9 = concatenate([upsample9, conv1], axis=3)
conv9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (upsample9)
conv9 = BatchNormalization() (conv9)
conv9 = Dropout(0.1) (conv9)
conv9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (conv9)
conv9 = BatchNormalization() (conv9)

outputs = Conv2D(1, (1, 1), activation='sigmoid') (conv9)

model = Model(inputs=[inputs], outputs=[outputs])
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 256, 256, 16) 448         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 256, 256, 16) 64          conv2d_20[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 256, 256, 16) 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 256, 256, 16) 2320        dropout_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 256, 256, 16) 64          conv2d_21[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 128, 128, 16) 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 128, 128, 32) 4640        max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 128, 128, 32) 128         conv2d_22[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 128, 128, 32) 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 128, 128, 32) 9248        dropout_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 128, 128, 32) 128         conv2d_23[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 64, 64, 32)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 64, 64, 64)   18496       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 64, 64, 64)   256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 64, 64, 64)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 64, 64, 64)   36928       dropout_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 64, 64, 64)   256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 32, 32, 64)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 32, 32, 128)  73856       max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 32, 32, 128)  512         conv2d_26[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 32, 32, 128)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 32, 32, 128)  147584      dropout_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 32, 32, 128)  512         conv2d_27[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 16, 16, 128)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 16, 16, 256)  295168      max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 16, 16, 256)  1024        conv2d_28[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 16, 16, 256)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 16, 16, 256)  590080      dropout_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 16, 16, 256)  1024        conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 32, 32, 128)  131200      batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 32, 32, 256)  0           conv2d_transpose_5[0][0]
#                                                                  batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 32, 32, 128)  295040      concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 32, 32, 128)  512         conv2d_30[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 32, 32, 128)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 32, 32, 128)  147584      dropout_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 32, 32, 128)  512         conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 64, 64, 64)   32832       batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 64, 64, 128)  0           conv2d_transpose_6[0][0]
#                                                                  batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 64, 64, 64)   73792       concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 64, 64, 64)   256         conv2d_32[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 64, 64, 64)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 64, 64, 64)   36928       dropout_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 64, 64, 64)   256         conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 128, 128, 32) 8224        batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 128, 128, 64) 0           conv2d_transpose_7[0][0]
#                                                                  batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 128, 128, 32) 18464       concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 128, 128, 32) 128         conv2d_34[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 128, 128, 32) 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 128, 128, 32) 9248        dropout_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 128, 128, 32) 128         conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 256, 256, 16) 2064        batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 256, 256, 32) 0           conv2d_transpose_8[0][0]
#                                                                  batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 256, 256, 16) 4624        concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 256, 256, 16) 64          conv2d_36[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 256, 256, 16) 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 256, 256, 16) 2320        dropout_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 256, 256, 16) 64          conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 256, 256, 1)  17          batch_normalization_36[0][0]
# ==================================================================================================
# Total params: 1,946,993
# Trainable params: 1,944,049
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %%
EPOCHS = 100
LEARNING_RATE = 0.0001
BATCH_SIZE = 16

# %%
from tensorboardcolab import TensorBoardColab, TensorBoardColabCallback
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from datetime import datetime
tbc=TensorBoardColab()
# Out:
# Wait for 8 seconds...
# TensorBoard link:
# https://5dd9c002.ngrok.io

# %%
model_path = "/content/drive/My Drive/datasets/road_mapper.h5"

checkpointer = ModelCheckpoint(model_path,
                             monitor="val_loss",
                             mode="min",
                             save_best_only = True,
                             verbose=1)

earlystopper = EarlyStopping(monitor = 'val_loss', 
                          min_delta = 0, 
                          patience = 5,
                          verbose = 1,
                          restore_best_weights = True)

lr_reducer = ReduceLROnPlateau(monitor='val_loss',
                               factor=0.1,
                               patience=4,
                               verbose=1,
                               epsilon=1e-4)

# %%
from keras import backend as K
def iou_coef(y_true, y_pred, smooth=1):
  intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
  union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
  iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
  
  return iou

def dice_coef(y_true, y_pred, smooth = 1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def soft_dice_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

# %%
opt = keras.optimizers.adam(LEARNING_RATE)
model.compile(
      optimizer=opt,
      loss=soft_dice_loss,
      metrics=[iou_coef])

# %%
history = model.fit(train_images,
                    train_masks/255,
                    validation_split = 0.1,
                    epochs=EPOCHS,
                    batch_size = BATCH_SIZE,
                    callbacks = [checkpointer, earlystopper, lr_reducer, TensorBoardColabCallback(tbc)]
                       )
# Out:
# Train on 720 samples, validate on 80 samples
# Epoch 1/100
# 720/720 [==============================] - 13s 18ms/step - loss: 0.8820 - iou_coef: 0.0587 - val_loss: 0.8323 - val_iou_coef: 0.0746
#
# Epoch 00001: val_loss improved from inf to 0.83233, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 2/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.8512 - iou_coef: 0.0715 - val_loss: 0.8226 - val_iou_coef: 0.0824
#
# Epoch 00002: val_loss improved from 0.83233 to 0.82264, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 3/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.8375 - iou_coef: 0.0772 - val_loss: 0.8088 - val_iou_coef: 0.0892
#
# Epoch 00003: val_loss improved from 0.82264 to 0.80884, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 4/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.8269 - iou_coef: 0.0827 - val_loss: 0.8060 - val_iou_coef: 0.0921
#
# Epoch 00004: val_loss improved from 0.80884 to 0.80605, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 5/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.8185 - iou_coef: 0.0875 - val_loss: 0.7932 - val_iou_coef: 0.0987
#
# Epoch 00005: val_loss improved from 0.80605 to 0.79321, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 6/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.8109 - iou_coef: 0.0914 - val_loss: 0.8007 - val_iou_coef: 0.0965
#
# Epoch 00006: val_loss did not improve from 0.79321
# Epoch 7/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.8056 - iou_coef: 0.0945 - val_loss: 0.7826 - val_iou_coef: 0.1047
#
# Epoch 00007: val_loss improved from 0.79321 to 0.78261, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 8/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.8009 - iou_coef: 0.0979 - val_loss: 0.7669 - val_iou_coef: 0.1128
#
# Epoch 00008: val_loss improved from 0.78261 to 0.76692, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 9/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.7952 - iou_coef: 0.1006 - val_loss: 0.7878 - val_iou_coef: 0.1044
#
# Epoch 00009: val_loss did not improve from 0.76692
# Epoch 10/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.7891 - iou_coef: 0.1036 - val_loss: 0.7759 - val_iou_coef: 0.1112
#
# Epoch 00010: val_loss did not improve from 0.76692
# Epoch 11/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.7830 - iou_coef: 0.1074 - val_loss: 0.7600 - val_iou_coef: 0.1212
#
# Epoch 00011: val_loss improved from 0.76692 to 0.75996, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 12/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.7789 - iou_coef: 0.1096 - val_loss: 0.7203 - val_iou_coef: 0.1385
#
# Epoch 00012: val_loss improved from 0.75996 to 0.72029, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 13/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.7720 - iou_coef: 0.1128 - val_loss: 0.7239 - val_iou_coef: 0.1336
#
# Epoch 00013: val_loss did not improve from 0.72029
# Epoch 14/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.7680 - iou_coef: 0.1165 - val_loss: 0.7222 - val_iou_coef: 0.1371
#
# Epoch 00014: val_loss did not improve from 0.72029
# Epoch 15/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.7624 - iou_coef: 0.1196 - val_loss: 0.7187 - val_iou_coef: 0.1405
#
# Epoch 00015: val_loss improved from 0.72029 to 0.71867, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 16/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.7581 - iou_coef: 0.1226 - val_loss: 0.7077 - val_iou_coef: 0.1512
#
# Epoch 00016: val_loss improved from 0.71867 to 0.70774, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 17/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.7541 - iou_coef: 0.1253 - val_loss: 0.7290 - val_iou_coef: 0.1452
#
# Epoch 00017: val_loss did not improve from 0.70774
# Epoch 18/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.7478 - iou_coef: 0.1291 - val_loss: 0.7008 - val_iou_coef: 0.1561
#
# Epoch 00018: val_loss improved from 0.70774 to 0.70081, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 19/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.7410 - iou_coef: 0.1328 - val_loss: 0.6820 - val_iou_coef: 0.1651
#
# Epoch 00019: val_loss improved from 0.70081 to 0.68204, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 20/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.7354 - iou_coef: 0.1363 - val_loss: 0.6749 - val_iou_coef: 0.1683
#
# Epoch 00020: val_loss improved from 0.68204 to 0.67487, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 21/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.7310 - iou_coef: 0.1394 - val_loss: 0.6935 - val_iou_coef: 0.1635
#
# Epoch 00021: val_loss did not improve from 0.67487
# Epoch 22/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.7236 - iou_coef: 0.1433 - val_loss: 0.6936 - val_iou_coef: 0.1635
#
# Epoch 00022: val_loss did not improve from 0.67487
# Epoch 23/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.7183 - iou_coef: 0.1468 - val_loss: 0.6789 - val_iou_coef: 0.1734
#
# Epoch 00023: val_loss did not improve from 0.67487
# Epoch 24/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.7151 - iou_coef: 0.1500 - val_loss: 0.6593 - val_iou_coef: 0.1777
#
# Epoch 00024: val_loss improved from 0.67487 to 0.65927, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 25/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.7082 - iou_coef: 0.1535 - val_loss: 0.6499 - val_iou_coef: 0.1838
#
# Epoch 00025: val_loss improved from 0.65927 to 0.64992, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 26/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.7031 - iou_coef: 0.1579 - val_loss: 0.6553 - val_iou_coef: 0.1833
#
# Epoch 00026: val_loss did not improve from 0.64992
# Epoch 27/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.6966 - iou_coef: 0.1616 - val_loss: 0.6591 - val_iou_coef: 0.1858
#
# Epoch 00027: val_loss did not improve from 0.64992
# Epoch 28/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.6904 - iou_coef: 0.1652 - val_loss: 0.6576 - val_iou_coef: 0.1826
#
# Epoch 00028: val_loss did not improve from 0.64992
# Epoch 29/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.6859 - iou_coef: 0.1688 - val_loss: 0.6410 - val_iou_coef: 0.1913
#
# Epoch 00029: val_loss improved from 0.64992 to 0.64105, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 30/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.6798 - iou_coef: 0.1731 - val_loss: 0.6479 - val_iou_coef: 0.1884
#
# Epoch 00030: val_loss did not improve from 0.64105
# Epoch 31/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.6754 - iou_coef: 0.1757 - val_loss: 0.6366 - val_iou_coef: 0.1943
#
# Epoch 00031: val_loss improved from 0.64105 to 0.63657, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 32/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.6670 - iou_coef: 0.1809 - val_loss: 0.6401 - val_iou_coef: 0.1947
#
# Epoch 00032: val_loss did not improve from 0.63657
# Epoch 33/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.6627 - iou_coef: 0.1838 - val_loss: 0.6471 - val_iou_coef: 0.1927
#
# Epoch 00033: val_loss did not improve from 0.63657
# Epoch 34/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.6564 - iou_coef: 0.1889 - val_loss: 0.6349 - val_iou_coef: 0.1936
#
# Epoch 00034: val_loss improved from 0.63657 to 0.63491, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 35/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.6498 - iou_coef: 0.1927 - val_loss: 0.6206 - val_iou_coef: 0.2044
#
# Epoch 00035: val_loss improved from 0.63491 to 0.62063, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 36/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.6432 - iou_coef: 0.1973 - val_loss: 0.6186 - val_iou_coef: 0.2046
#
# Epoch 00036: val_loss improved from 0.62063 to 0.61860, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 37/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.6390 - iou_coef: 0.2007 - val_loss: 0.6225 - val_iou_coef: 0.2027
#
# Epoch 00037: val_loss did not improve from 0.61860
# Epoch 38/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.6321 - iou_coef: 0.2051 - val_loss: 0.6108 - val_iou_coef: 0.2097
#
# Epoch 00038: val_loss improved from 0.61860 to 0.61082, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 39/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.6261 - iou_coef: 0.2100 - val_loss: 0.6284 - val_iou_coef: 0.2034
#
# Epoch 00039: val_loss did not improve from 0.61082
# Epoch 40/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.6195 - iou_coef: 0.2146 - val_loss: 0.6278 - val_iou_coef: 0.2034
#
# Epoch 00040: val_loss did not improve from 0.61082
# Epoch 41/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.6128 - iou_coef: 0.2189 - val_loss: 0.6062 - val_iou_coef: 0.2148
#
# Epoch 00041: val_loss improved from 0.61082 to 0.60622, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 42/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.6050 - iou_coef: 0.2251 - val_loss: 0.6026 - val_iou_coef: 0.2159
#
# Epoch 00042: val_loss improved from 0.60622 to 0.60256, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 43/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.5992 - iou_coef: 0.2290 - val_loss: 0.5976 - val_iou_coef: 0.2193
#
# Epoch 00043: val_loss improved from 0.60256 to 0.59759, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 44/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.5930 - iou_coef: 0.2336 - val_loss: 0.5945 - val_iou_coef: 0.2249
#
# Epoch 00044: val_loss improved from 0.59759 to 0.59450, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 45/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.5864 - iou_coef: 0.2391 - val_loss: 0.5922 - val_iou_coef: 0.2272
#
# Epoch 00045: val_loss improved from 0.59450 to 0.59223, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 46/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.5797 - iou_coef: 0.2437 - val_loss: 0.5859 - val_iou_coef: 0.2289
#
# Epoch 00046: val_loss improved from 0.59223 to 0.58590, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 47/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.5722 - iou_coef: 0.2496 - val_loss: 0.5771 - val_iou_coef: 0.2373
#
# Epoch 00047: val_loss improved from 0.58590 to 0.57705, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 48/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.5665 - iou_coef: 0.2544 - val_loss: 0.5712 - val_iou_coef: 0.2415
#
# Epoch 00048: val_loss improved from 0.57705 to 0.57117, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 49/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.5609 - iou_coef: 0.2593 - val_loss: 0.5708 - val_iou_coef: 0.2448
#
# Epoch 00049: val_loss improved from 0.57117 to 0.57078, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 50/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.5563 - iou_coef: 0.2640 - val_loss: 0.5616 - val_iou_coef: 0.2520
#
# Epoch 00050: val_loss improved from 0.57078 to 0.56159, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 51/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.5473 - iou_coef: 0.2702 - val_loss: 0.5512 - val_iou_coef: 0.2588
#
# Epoch 00051: val_loss improved from 0.56159 to 0.55115, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 52/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.5434 - iou_coef: 0.2737 - val_loss: 0.5493 - val_iou_coef: 0.2619
#
# Epoch 00052: val_loss improved from 0.55115 to 0.54932, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 53/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.5377 - iou_coef: 0.2795 - val_loss: 0.5448 - val_iou_coef: 0.2703
#
# Epoch 00053: val_loss improved from 0.54932 to 0.54484, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 54/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.5294 - iou_coef: 0.2856 - val_loss: 0.5324 - val_iou_coef: 0.2779
#
# Epoch 00054: val_loss improved from 0.54484 to 0.53240, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 55/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.5241 - iou_coef: 0.2906 - val_loss: 0.5325 - val_iou_coef: 0.2790
#
# Epoch 00055: val_loss did not improve from 0.53240
# Epoch 56/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.5180 - iou_coef: 0.2950 - val_loss: 0.5224 - val_iou_coef: 0.2868
#
# Epoch 00056: val_loss improved from 0.53240 to 0.52235, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 57/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.5144 - iou_coef: 0.2984 - val_loss: 0.5177 - val_iou_coef: 0.2917
#
# Epoch 00057: val_loss improved from 0.52235 to 0.51775, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 58/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.5065 - iou_coef: 0.3057 - val_loss: 0.5089 - val_iou_coef: 0.2979
#
# Epoch 00058: val_loss improved from 0.51775 to 0.50893, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 59/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.5033 - iou_coef: 0.3086 - val_loss: 0.5070 - val_iou_coef: 0.2994
#
# Epoch 00059: val_loss improved from 0.50893 to 0.50704, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 60/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4995 - iou_coef: 0.3125 - val_loss: 0.4985 - val_iou_coef: 0.3085
#
# Epoch 00060: val_loss improved from 0.50704 to 0.49854, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 61/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4941 - iou_coef: 0.3180 - val_loss: 0.4929 - val_iou_coef: 0.3122
#
# Epoch 00061: val_loss improved from 0.49854 to 0.49288, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 62/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4899 - iou_coef: 0.3216 - val_loss: 0.4978 - val_iou_coef: 0.3100
#
# Epoch 00062: val_loss did not improve from 0.49288
# Epoch 63/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4849 - iou_coef: 0.3258 - val_loss: 0.4922 - val_iou_coef: 0.3202
#
# Epoch 00063: val_loss improved from 0.49288 to 0.49224, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 64/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4833 - iou_coef: 0.3286 - val_loss: 0.4845 - val_iou_coef: 0.3223
#
# Epoch 00064: val_loss improved from 0.49224 to 0.48447, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 65/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4766 - iou_coef: 0.3329 - val_loss: 0.4836 - val_iou_coef: 0.3244
#
# Epoch 00065: val_loss improved from 0.48447 to 0.48359, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 66/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4729 - iou_coef: 0.3363 - val_loss: 0.4716 - val_iou_coef: 0.3318
#
# Epoch 00066: val_loss improved from 0.48359 to 0.47165, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 67/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4707 - iou_coef: 0.3402 - val_loss: 0.4711 - val_iou_coef: 0.3337
#
# Epoch 00067: val_loss improved from 0.47165 to 0.47111, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 68/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4676 - iou_coef: 0.3425 - val_loss: 0.4660 - val_iou_coef: 0.3369
#
# Epoch 00068: val_loss improved from 0.47111 to 0.46605, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 69/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4651 - iou_coef: 0.3448 - val_loss: 0.4639 - val_iou_coef: 0.3387
#
# Epoch 00069: val_loss improved from 0.46605 to 0.46390, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 70/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4603 - iou_coef: 0.3485 - val_loss: 0.4670 - val_iou_coef: 0.3378
#
# Epoch 00070: val_loss did not improve from 0.46390
# Epoch 71/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4586 - iou_coef: 0.3515 - val_loss: 0.4624 - val_iou_coef: 0.3416
#
# Epoch 00071: val_loss improved from 0.46390 to 0.46237, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 72/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4562 - iou_coef: 0.3540 - val_loss: 0.4582 - val_iou_coef: 0.3476
#
# Epoch 00072: val_loss improved from 0.46237 to 0.45823, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 73/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4524 - iou_coef: 0.3579 - val_loss: 0.4571 - val_iou_coef: 0.3479
#
# Epoch 00073: val_loss improved from 0.45823 to 0.45708, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 74/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4504 - iou_coef: 0.3603 - val_loss: 0.4539 - val_iou_coef: 0.3518
#
# Epoch 00074: val_loss improved from 0.45708 to 0.45390, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 75/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4482 - iou_coef: 0.3625 - val_loss: 0.4492 - val_iou_coef: 0.3537
#
# Epoch 00075: val_loss improved from 0.45390 to 0.44923, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 76/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4458 - iou_coef: 0.3646 - val_loss: 0.4502 - val_iou_coef: 0.3545
#
# Epoch 00076: val_loss did not improve from 0.44923
# Epoch 77/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4429 - iou_coef: 0.3678 - val_loss: 0.4494 - val_iou_coef: 0.3566
#
# Epoch 00077: val_loss did not improve from 0.44923
# Epoch 78/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4408 - iou_coef: 0.3699 - val_loss: 0.4481 - val_iou_coef: 0.3589
#
# Epoch 00078: val_loss improved from 0.44923 to 0.44811, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 79/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4387 - iou_coef: 0.3721 - val_loss: 0.4444 - val_iou_coef: 0.3606
#
# Epoch 00079: val_loss improved from 0.44811 to 0.44441, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 80/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4380 - iou_coef: 0.3726 - val_loss: 0.4443 - val_iou_coef: 0.3609
#
# Epoch 00080: val_loss improved from 0.44441 to 0.44434, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 81/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4335 - iou_coef: 0.3760 - val_loss: 0.4417 - val_iou_coef: 0.3629
#
# Epoch 00081: val_loss improved from 0.44434 to 0.44174, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 82/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4307 - iou_coef: 0.3775 - val_loss: 0.4343 - val_iou_coef: 0.3690
#
# Epoch 00082: val_loss improved from 0.44174 to 0.43429, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 83/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4313 - iou_coef: 0.3801 - val_loss: 0.4390 - val_iou_coef: 0.3667
#
# Epoch 00083: val_loss did not improve from 0.43429
# Epoch 84/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4314 - iou_coef: 0.3801 - val_loss: 0.4410 - val_iou_coef: 0.3659
#
# Epoch 00084: val_loss did not improve from 0.43429
# Epoch 85/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4271 - iou_coef: 0.3834 - val_loss: 0.4341 - val_iou_coef: 0.3709
#
# Epoch 00085: val_loss improved from 0.43429 to 0.43412, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 86/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4238 - iou_coef: 0.3851 - val_loss: 0.4355 - val_iou_coef: 0.3706
#
# Epoch 00086: val_loss did not improve from 0.43412
# Epoch 87/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4227 - iou_coef: 0.3875 - val_loss: 0.4288 - val_iou_coef: 0.3752
#
# Epoch 00087: val_loss improved from 0.43412 to 0.42876, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 88/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4232 - iou_coef: 0.3881 - val_loss: 0.4309 - val_iou_coef: 0.3741
#
# Epoch 00088: val_loss did not improve from 0.42876
# Epoch 89/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4219 - iou_coef: 0.3899 - val_loss: 0.4277 - val_iou_coef: 0.3755
#
# Epoch 00089: val_loss improved from 0.42876 to 0.42766, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 90/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4206 - iou_coef: 0.3899 - val_loss: 0.4280 - val_iou_coef: 0.3767
#
# Epoch 00090: val_loss did not improve from 0.42766
# Epoch 91/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4191 - iou_coef: 0.3917 - val_loss: 0.4278 - val_iou_coef: 0.3759
#
# Epoch 00091: val_loss did not improve from 0.42766
# Epoch 92/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4154 - iou_coef: 0.3949 - val_loss: 0.4219 - val_iou_coef: 0.3806
#
# Epoch 00092: val_loss improved from 0.42766 to 0.42190, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 93/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4143 - iou_coef: 0.3963 - val_loss: 0.4247 - val_iou_coef: 0.3798
#
# Epoch 00093: val_loss did not improve from 0.42190
# Epoch 94/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4150 - iou_coef: 0.3974 - val_loss: 0.4209 - val_iou_coef: 0.3825
#
# Epoch 00094: val_loss improved from 0.42190 to 0.42092, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 95/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4136 - iou_coef: 0.3987 - val_loss: 0.4179 - val_iou_coef: 0.3839
#
# Epoch 00095: val_loss improved from 0.42092 to 0.41791, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 96/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4102 - iou_coef: 0.4007 - val_loss: 0.4173 - val_iou_coef: 0.3849
#
# Epoch 00096: val_loss improved from 0.41791 to 0.41734, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 97/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4100 - iou_coef: 0.4024 - val_loss: 0.4195 - val_iou_coef: 0.3846
#
# Epoch 00097: val_loss did not improve from 0.41734
# Epoch 98/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4075 - iou_coef: 0.4032 - val_loss: 0.4160 - val_iou_coef: 0.3868
#
# Epoch 00098: val_loss improved from 0.41734 to 0.41605, saving model to /content/drive/My Drive/datasets/road_mapper.h5
# Epoch 99/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4063 - iou_coef: 0.4040 - val_loss: 0.4176 - val_iou_coef: 0.3862
#
# Epoch 00099: val_loss did not improve from 0.41605
# Epoch 100/100
# 720/720 [==============================] - 10s 14ms/step - loss: 0.4065 - iou_coef: 0.4041 - val_loss: 0.4167 - val_iou_coef: 0.3856
#
# Epoch 00100: val_loss did not improve from 0.41605

# %%
model.save("/content/drive/My Drive/datasets/road_mapper_final.h5")

# %%
model = load_model("/content/drive/My Drive/datasets/road_mapper_final.h5", custom_objects={'soft_dice_loss': soft_dice_loss, 'iou_coef': iou_coef})

# %%
model.evaluate(test_images, test_masks)
# Out:
# 200/200 [==============================] - 2s 11ms/step
# [-0.18390475749969482, 2.150346250534058]

# %%
predictions = model.predict(test_images, verbose=1)
# Out:
# 200/200 [==============================] - 2s 11ms/step

# %%
thresh_val = 0.1
predicton_threshold = (predictions > thresh_val).astype(np.uint8)

# %%
ix = random.randint(0, len(predictions))
num_samples = 10

f = plt.figure(figsize = (15, 25))
for i in range(1, num_samples*4, 4):
  ix = random.randint(0, len(predictions))

  f.add_subplot(num_samples, 4, i)
  imshow(test_images[ix][:,:,0])
  plt.title("Image")
  plt.axis('off')

  f.add_subplot(num_samples, 4, i+1)
  imshow(np.squeeze(test_masks[ix][:,:,0]))
  plt.title("Groud Truth")
  plt.axis('off')

  f.add_subplot(num_samples, 4, i+2)
  imshow(np.squeeze(predictions[ix][:,:,0]))
  plt.title("Prediction")
  plt.axis('off')

  f.add_subplot(num_samples, 4, i+3)
  imshow(np.squeeze(predicton_threshold[ix][:,:,0]))
  plt.title("thresholded at {}".format(thresh_val))
  plt.axis('off')

plt.show()

# %%
newimg = cv2.imread('/content/drive/My Drive/datasets/img1.tiff')
resized_newimg = cv2.resize(newimg, (256, 256))
print(resized_newimg.shape)
# Out:
# (256, 256, 3)

# %%
plt.imshow(resized_newimg)

# %%
listimg = list()
listimg.append(resized_newimg)
listimg = np.asarray(listimg)
predictions_new = model.predict(listimg, verbose=1)
# Out:
# 1/1 [==============================] - 0s 21ms/step

# %%
plt.imshow(np.squeeze(predictions_new[0]))
